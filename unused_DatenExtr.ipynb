# %%
import fitz
import numpy
import PyPDF2
#from xml.dom import DomstringSizeErr
#nltk
import nltk
nltk.download('punkt') #nltk.tokenize.punkt module.  https://www.nltk.org/_modules/nltk/tokenize/punkt.html
nltk.download('averaged_perceptron_tagger') #nltk.tag.perceptron module, https://explosion.ai/blog/part-of-speech-pos-tagger-in-python
nltk.download('maxent_ne_chunker') #https://www.kaggle.com/datasets/nltkdata/maxent-ne-chunker , https://www.tomaarsen.com/nltk/api/nltk.chunk.named_entity.html
nltk.download('words') #list of str https://www.nltk.org/api/nltk.corpus.reader.html?highlight=words#nltk.corpus.reader.AlignedCorpusReader.words
from nltk.tokenize import sent_tokenize
#from nltk.stem import WordNetLemmatizer
#nltk.download('omw-1.4')
#Spacy
import spacy
import networkx as nx
from spacy import displacy
NER = spacy.load("en_core_web_sm")
#Stopwords
from nltk.corpus import stopwords
nltk.download('stopwords')
stoplist = stopwords.words('english')
stopset = set(stopwords.words('english'))

#import aspose.words as aw
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Jana\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Jana\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\Jana\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Jana\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Jana\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
pdf_path = 'C:/Users/Jana/OneDrive/Dokumente/Desktop/Uni/Master/Thesis/PaperDatenextraktion/IARJSET7.pdf'
#pdf_path = open(str(filePath)+'Data Mining Tools.pdf', 'rb')
docPyPDF = PyPDF2.PdfFileReader(pdf_path)
docFitz = fitz.open(pdf_path)
page = docPyPDF[1]
text = page.get_text("text")

print('PyPDF:\n',  docPyPDF.getDocumentInfo())
print('Fitz:\n',  docFitz.metadata)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 5>()
#       3 docPyPDF = PyPDF2.PdfFileReader(pdf_path)
#       4 docFitz = fitz.open(pdf_path)
# ----> 5 page = docPyPDF[1]
#       6 text = page.get_text("text")
#       8 print('PyPDF:\n',  docPyPDF.getDocumentInfo())
#
# TypeError: 'PdfFileReader' object is not subscriptable

# %%
#Tokenisierung einzelner Wörter
#tokens = nltk.word_tokenize(exmpl)
#Tokenisierung Sätze
tokens=sent_tokenize(text)
print(sent_seg)
# Out:
# ['IARJSET \n \nISSN (Online) 2393-8021 \n  \n \nISSN (Print) 2394-1588 \n \n        International Advanced Research Journal in Science, Engineering and Technology \nISO 3297:2007 Certified \nVol.', '5, Issue 1, January 2018 \n \nCopyright to IARJSET \n                                             DOI  10.17148/IARJSET.2018.517                                                             41 \nIntroduction to IOT \n \nPradyumna Gokhale1, Omkar Bhat2, Sagar Bhat3 \nIT Dept., Smt.', 'Kashibai Navale College of Engineering1-3 \n \nAbstract: The phrase Internet of Things (IoT) refers to connecting various physical devices and objects throughout the \nworld via internet.', 'The term IoT was firstly proposed by Kevin Ashton in 1999.The following section illustrates basics \nof IoT.', 'It deals with various layers used in IoT and some basic terms related to it.', 'It is basically expansion of services \nprovided by Internet.', 'This section also presents the architecture of IoT.', 'For example, when the household devices of \nour daily life connect with the internet the system can be called a Smart-Home in IoT environment.', 'The IoT is not just \ndeep vision for future.', 'It is already under implementation and is having an impact on more than just technological \ndevelopment.', 'Keywords: Internet of Things (IoT), Service Oriented Architecture (SoA).', 'I.', 'INTRODUCTION \n \nThe Internet of Things (IoT) is the network of physical objects—devices, instruments, vehicles, buildings and other \nitems embedded with electronics, circuits ,software, sensors and network connectivity that enables these objects to \ncollect and exchange data.', 'The Internet of Things allows objects to be sensed and controlled remotely across existing \nnetwork infrastructure, creating opportunities for more direct integration of the physical world into computer-based \nsystems, and resulting in improved efficiency and accuracy.', 'The concept of a network of smart devices was discussed as early as 1982, with a modified Coke machine at Carnegie \nMellon University becoming the first internet-connected appliance [3], able to report its inventory and whether newly \nloaded drinks were cold.', 'Kevin Ashton (born 1968) is a British technology pioneer who is known for inventing the \nterm "the Internet of Things" to describe a system where the Internet is connected to the physical world via ubiquitous \nsensors.', 'IoT is able to interact without human intervention.', 'Some preliminary IoT applications have been already developed in \nhealthcare, transportation, and automotive industries.', 'IoT technologies are at their infant stages; however, many new \ndevelopments have occurred in the integration of objects with sensors in the Internet.', 'The development of IoT involves \nmany issues such as infrastructure, communications, interfaces, protocols, and standards.', 'The objective of this paper is to give general concept of IoT, the architecture and layers in IoT, some basic terms \nassociated with it and the services provided.', 'II.', 'CONCEPT OF IOT \n   \n Kevin Ashton firstly proposed the concept of IoT in 1999, and he referred the IoT as uniquely identifiable connected \nobjects with radio-frequency identification (RFID) technology.', 'However, the exact definition of IoT is still in the \nforming process that is subject to the perspectives taken.', 'IoT was generally defined as “dynamic global network \ninfrastructure with self-configuring capabilities based on standards and communication protocols”.', 'Fig.2.1 Evolution of Internet [1]']

# %%
#tokens=[word.lower() for word in tokens if word.isalpha()]
import string

tokens = [''.join(letter for letter in word if letter not in string.punctuation) for word in tokens if word]
#print(tokens)

# Herasufiltern Stop words
exmpl_filtered_sw = []
for w in tokens:
    if w not in stopset:
        exmpl_filtered_sw.append(w)
print(exmpl_filtered_sw)
# Out:
# ['IARJSET \n \nISSN Online 23938021 \n  \n \nISSN Print 23941588 \n \n        International Advanced Research Journal in Science Engineering and Technology \nISO 32972007 Certified \nVol', '5 Issue 1 January 2018 \n \nCopyright to IARJSET \n                                             DOI  1017148IARJSET2018517                                                             41 \nIntroduction to IOT \n \nPradyumna Gokhale1 Omkar Bhat2 Sagar Bhat3 \nIT Dept Smt', 'Kashibai Navale College of Engineering13 \n \nAbstract The phrase Internet of Things IoT refers to connecting various physical devices and objects throughout the \nworld via internet', 'The term IoT was firstly proposed by Kevin Ashton in 1999The following section illustrates basics \nof IoT', 'It deals with various layers used in IoT and some basic terms related to it', 'It is basically expansion of services \nprovided by Internet', 'This section also presents the architecture of IoT', 'For example when the household devices of \nour daily life connect with the internet the system can be called a SmartHome in IoT environment', 'The IoT is not just \ndeep vision for future', 'It is already under implementation and is having an impact on more than just technological \ndevelopment', 'Keywords Internet of Things IoT Service Oriented Architecture SoA', 'I', 'INTRODUCTION \n \nThe Internet of Things IoT is the network of physical objects—devices instruments vehicles buildings and other \nitems embedded with electronics circuits software sensors and network connectivity that enables these objects to \ncollect and exchange data', 'The Internet of Things allows objects to be sensed and controlled remotely across existing \nnetwork infrastructure creating opportunities for more direct integration of the physical world into computerbased \nsystems and resulting in improved efficiency and accuracy', 'The concept of a network of smart devices was discussed as early as 1982 with a modified Coke machine at Carnegie \nMellon University becoming the first internetconnected appliance 3 able to report its inventory and whether newly \nloaded drinks were cold', 'Kevin Ashton born 1968 is a British technology pioneer who is known for inventing the \nterm the Internet of Things to describe a system where the Internet is connected to the physical world via ubiquitous \nsensors', 'IoT is able to interact without human intervention', 'Some preliminary IoT applications have been already developed in \nhealthcare transportation and automotive industries', 'IoT technologies are at their infant stages however many new \ndevelopments have occurred in the integration of objects with sensors in the Internet', 'The development of IoT involves \nmany issues such as infrastructure communications interfaces protocols and standards', 'The objective of this paper is to give general concept of IoT the architecture and layers in IoT some basic terms \nassociated with it and the services provided', 'II', 'CONCEPT OF IOT \n   \n Kevin Ashton firstly proposed the concept of IoT in 1999 and he referred the IoT as uniquely identifiable connected \nobjects with radiofrequency identification RFID technology', 'However the exact definition of IoT is still in the \nforming process that is subject to the perspectives taken', 'IoT was generally defined as “dynamic global network \ninfrastructure with selfconfiguring capabilities based on standards and communication protocols”', 'Fig21 Evolution of Internet 1']

# %%
exmpl_postagged = nltk.pos_tag(exmpl_filtered_sw)
print(exmpl_postagged)
# Out:
# [('IARJSET \n \nISSN Online 23938021 \n  \n \nISSN Print 23941588 \n \n        International Advanced Research Journal in Science Engineering and Technology \nISO 32972007 Certified \nVol', 'NNP'), ('5 Issue 1 January 2018 \n \nCopyright to IARJSET \n                                             DOI  1017148IARJSET2018517                                                             41 \nIntroduction to IOT \n \nPradyumna Gokhale1 Omkar Bhat2 Sagar Bhat3 \nIT Dept Smt', 'CD'), ('Kashibai Navale College of Engineering13 \n \nAbstract The phrase Internet of Things IoT refers to connecting various physical devices and objects throughout the \nworld via internet', 'NNP'), ('The term IoT was firstly proposed by Kevin Ashton in 1999The following section illustrates basics \nof IoT', 'NNP'), ('It deals with various layers used in IoT and some basic terms related to it', 'NNP'), ('It is basically expansion of services \nprovided by Internet', 'NNP'), ('This section also presents the architecture of IoT', 'NNP'), ('For example when the household devices of \nour daily life connect with the internet the system can be called a SmartHome in IoT environment', 'NNP'), ('The IoT is not just \ndeep vision for future', 'NNP'), ('It is already under implementation and is having an impact on more than just technological \ndevelopment', 'NNP'), ('Keywords Internet of Things IoT Service Oriented Architecture SoA', 'NNP'), ('I', 'PRP'), ('INTRODUCTION \n \nThe Internet of Things IoT is the network of physical objects—devices instruments vehicles buildings and other \nitems embedded with electronics circuits software sensors and network connectivity that enables these objects to \ncollect and exchange data', 'NNP'), ('The Internet of Things allows objects to be sensed and controlled remotely across existing \nnetwork infrastructure creating opportunities for more direct integration of the physical world into computerbased \nsystems and resulting in improved efficiency and accuracy', 'NNP'), ('The concept of a network of smart devices was discussed as early as 1982 with a modified Coke machine at Carnegie \nMellon University becoming the first internetconnected appliance 3 able to report its inventory and whether newly \nloaded drinks were cold', 'NNP'), ('Kevin Ashton born 1968 is a British technology pioneer who is known for inventing the \nterm the Internet of Things to describe a system where the Internet is connected to the physical world via ubiquitous \nsensors', 'NNP'), ('IoT is able to interact without human intervention', 'NNP'), ('Some preliminary IoT applications have been already developed in \nhealthcare transportation and automotive industries', 'NNP'), ('IoT technologies are at their infant stages however many new \ndevelopments have occurred in the integration of objects with sensors in the Internet', 'NNP'), ('The development of IoT involves \nmany issues such as infrastructure communications interfaces protocols and standards', 'NNP'), ('The objective of this paper is to give general concept of IoT the architecture and layers in IoT some basic terms \nassociated with it and the services provided', 'NNP'), ('II', 'NNP'), ('CONCEPT OF IOT \n   \n Kevin Ashton firstly proposed the concept of IoT in 1999 and he referred the IoT as uniquely identifiable connected \nobjects with radiofrequency identification RFID technology', 'NNP'), ('However the exact definition of IoT is still in the \nforming process that is subject to the perspectives taken', 'NNP'), ('IoT was generally defined as “dynamic global network \ninfrastructure with selfconfiguring capabilities based on standards and communication protocols”', 'NNP'), ('Fig21 Evolution of Internet 1', 'NNP')]

# %%
exmpl_chunks = nltk.ne_chunk(exmpl_postagged)
print(exmpl_chunks)
# Out:
# (S
#   IARJSET
#
# ISSN Online 23938021
#
#
# ISSN Print 23941588
#
#         International Advanced Research Journal in Science Engineering and Technology
# ISO 32972007 Certified
# Vol/NNP
#   5 Issue 1 January 2018
#
# Copyright to IARJSET
#                                              DOI  1017148IARJSET2018517                                                             41
# Introduction to IOT
#
# Pradyumna Gokhale1 Omkar Bhat2 Sagar Bhat3
# IT Dept Smt/CD
#   Kashibai Navale College of Engineering13
#
# Abstract The phrase Internet of Things IoT refers to connecting various physical devices and objects throughout the
# world via internet/NNP
#   The term IoT was firstly proposed by Kevin Ashton in 1999The following section illustrates basics
# of IoT/NNP
#   It deals with various layers used in IoT and some basic terms related to it/NNP
#   It is basically expansion of services
# provided by Internet/NNP
#   This section also presents the architecture of IoT/NNP
#   For example when the household devices of
# our daily life connect with the internet the system can be called a SmartHome in IoT environment/NNP
#   The IoT is not just
# deep vision for future/NNP
#   It is already under implementation and is having an impact on more than just technological
# development/NNP
#   Keywords Internet of Things IoT Service Oriented Architecture SoA/NNP
#   I/PRP
#   INTRODUCTION
#
# The Internet of Things IoT is the network of physical objects—devices instruments vehicles buildings and other
# items embedded with electronics circuits software sensors and network connectivity that enables these objects to
# collect and exchange data/NNP
#   The Internet of Things allows objects to be sensed and controlled remotely across existing
# network infrastructure creating opportunities for more direct integration of the physical world into computerbased
# systems and resulting in improved efficiency and accuracy/NNP
#   The concept of a network of smart devices was discussed as early as 1982 with a modified Coke machine at Carnegie
# Mellon University becoming the first internetconnected appliance 3 able to report its inventory and whether newly
# loaded drinks were cold/NNP
#   Kevin Ashton born 1968 is a British technology pioneer who is known for inventing the
# term the Internet of Things to describe a system where the Internet is connected to the physical world via ubiquitous
# sensors/NNP
#   IoT is able to interact without human intervention/NNP
#   Some preliminary IoT applications have been already developed in
# healthcare transportation and automotive industries/NNP
#   IoT technologies are at their infant stages however many new
# developments have occurred in the integration of objects with sensors in the Internet/NNP
#   The development of IoT involves
# many issues such as infrastructure communications interfaces protocols and standards/NNP
#   The objective of this paper is to give general concept of IoT the architecture and layers in IoT some basic terms
# associated with it and the services provided/NNP
#   II/NNP
#   CONCEPT OF IOT
#
#  Kevin Ashton firstly proposed the concept of IoT in 1999 and he referred the IoT as uniquely identifiable connected
# objects with radiofrequency identification RFID technology/NNP
#   However the exact definition of IoT is still in the
# forming process that is subject to the perspectives taken/NNP
#   IoT was generally defined as “dynamic global network
# infrastructure with selfconfiguring capabilities based on standards and communication protocols”/NNP
#   Fig21 Evolution of Internet 1/NNP)

# %%
pattern = 'NP: {<DT>?<JJ>*<NN>}'
cp = nltk.RegexpParser(pattern)
cs = cp.parse(exmpl_postagged)
print(cs)
# Out:
# (S
#   IARJSET
#
# ISSN Online 23938021
#
#
# ISSN Print 23941588
#
#         International Advanced Research Journal in Science Engineering and Technology
# ISO 32972007 Certified
# Vol/NNP
#   5 Issue 1 January 2018
#
# Copyright to IARJSET
#                                              DOI  1017148IARJSET2018517                                                             41
# Introduction to IOT
#
# Pradyumna Gokhale1 Omkar Bhat2 Sagar Bhat3
# IT Dept Smt/CD
#   Kashibai Navale College of Engineering13
#
# Abstract The phrase Internet of Things IoT refers to connecting various physical devices and objects throughout the
# world via internet/NNP
#   The term IoT was firstly proposed by Kevin Ashton in 1999The following section illustrates basics
# of IoT/NNP
#   It deals with various layers used in IoT and some basic terms related to it/NNP
#   It is basically expansion of services
# provided by Internet/NNP
#   This section also presents the architecture of IoT/NNP
#   For example when the household devices of
# our daily life connect with the internet the system can be called a SmartHome in IoT environment/NNP
#   The IoT is not just
# deep vision for future/NNP
#   It is already under implementation and is having an impact on more than just technological
# development/NNP
#   Keywords Internet of Things IoT Service Oriented Architecture SoA/NNP
#   I/PRP
#   INTRODUCTION
#
# The Internet of Things IoT is the network of physical objects—devices instruments vehicles buildings and other
# items embedded with electronics circuits software sensors and network connectivity that enables these objects to
# collect and exchange data/NNP
#   The Internet of Things allows objects to be sensed and controlled remotely across existing
# network infrastructure creating opportunities for more direct integration of the physical world into computerbased
# systems and resulting in improved efficiency and accuracy/NNP
#   The concept of a network of smart devices was discussed as early as 1982 with a modified Coke machine at Carnegie
# Mellon University becoming the first internetconnected appliance 3 able to report its inventory and whether newly
# loaded drinks were cold/NNP
#   Kevin Ashton born 1968 is a British technology pioneer who is known for inventing the
# term the Internet of Things to describe a system where the Internet is connected to the physical world via ubiquitous
# sensors/NNP
#   IoT is able to interact without human intervention/NNP
#   Some preliminary IoT applications have been already developed in
# healthcare transportation and automotive industries/NNP
#   IoT technologies are at their infant stages however many new
# developments have occurred in the integration of objects with sensors in the Internet/NNP
#   The development of IoT involves
# many issues such as infrastructure communications interfaces protocols and standards/NNP
#   The objective of this paper is to give general concept of IoT the architecture and layers in IoT some basic terms
# associated with it and the services provided/NNP
#   II/NNP
#   CONCEPT OF IOT
#
#  Kevin Ashton firstly proposed the concept of IoT in 1999 and he referred the IoT as uniquely identifiable connected
# objects with radiofrequency identification RFID technology/NNP
#   However the exact definition of IoT is still in the
# forming process that is subject to the perspectives taken/NNP
#   IoT was generally defined as “dynamic global network
# infrastructure with selfconfiguring capabilities based on standards and communication protocols”/NNP
#   Fig21 Evolution of Internet 1/NNP)

# %%
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint
iob_tagged = tree2conlltags(cs)
pprint(iob_tagged)
# Out:
# [('IARJSET \n'
#   ' \n'
#   'ISSN Online 23938021 \n'
#   '  \n'
#   ' \n'
#   'ISSN Print 23941588 \n'
#   ' \n'
#   '        International Advanced Research Journal in Science Engineering and '
#   'Technology \n'
#   'ISO 32972007 Certified \n'
#   'Vol',
#   'NNP',
#   'O'),
#  ('5 Issue 1 January 2018 \n'
#   ' \n'
#   'Copyright to IARJSET \n'
#   '                                             DOI  '
#   '1017148IARJSET2018517                                                             '
#   '41 \n'
#   'Introduction to IOT \n'
#   ' \n'
#   'Pradyumna Gokhale1 Omkar Bhat2 Sagar Bhat3 \n'
#   'IT Dept Smt',
#   'CD',
#   'O'),
#  ('Kashibai Navale College of Engineering13 \n'
#   ' \n'
#   'Abstract The phrase Internet of Things IoT refers to connecting various '
#   'physical devices and objects throughout the \n'
#   'world via internet',
#   'NNP',
#   'O'),
#  ('The term IoT was firstly proposed by Kevin Ashton in 1999The following '
#   'section illustrates basics \n'
#   'of IoT',
#   'NNP',
#   'O'),
#  ('It deals with various layers used in IoT and some basic terms related to it',
#   'NNP',
#   'O'),
#  ('It is basically expansion of services \nprovided by Internet', 'NNP', 'O'),
#  ('This section also presents the architecture of IoT', 'NNP', 'O'),
#  ('For example when the household devices of \n'
#   'our daily life connect with the internet the system can be called a '
#   'SmartHome in IoT environment',
#   'NNP',
#   'O'),
#  ('The IoT is not just \ndeep vision for future', 'NNP', 'O'),
#  ('It is already under implementation and is having an impact on more than '
#   'just technological \n'
#   'development',
#   'NNP',
#   'O'),
#  ('Keywords Internet of Things IoT Service Oriented Architecture SoA',
#   'NNP',
#   'O'),
#  ('I', 'PRP', 'O'),
#  ('INTRODUCTION \n'
#   ' \n'
#   'The Internet of Things IoT is the network of physical objects—devices '
#   'instruments vehicles buildings and other \n'
#   'items embedded with electronics circuits software sensors and network '
#   'connectivity that enables these objects to \n'
#   'collect and exchange data',
#   'NNP',
#   'O'),
#  ('The Internet of Things allows objects to be sensed and controlled remotely '
#   'across existing \n'
#   'network infrastructure creating opportunities for more direct integration '
#   'of the physical world into computerbased \n'
#   'systems and resulting in improved efficiency and accuracy',
#   'NNP',
#   'O'),
#  ('The concept of a network of smart devices was discussed as early as 1982 '
#   'with a modified Coke machine at Carnegie \n'
#   'Mellon University becoming the first internetconnected appliance 3 able to '
#   'report its inventory and whether newly \n'
#   'loaded drinks were cold',
#   'NNP',
#   'O'),
#  ('Kevin Ashton born 1968 is a British technology pioneer who is known for '
#   'inventing the \n'
#   'term the Internet of Things to describe a system where the Internet is '
#   'connected to the physical world via ubiquitous \n'
#   'sensors',
#   'NNP',
#   'O'),
#  ('IoT is able to interact without human intervention', 'NNP', 'O'),
#  ('Some preliminary IoT applications have been already developed in \n'
#   'healthcare transportation and automotive industries',
#   'NNP',
#   'O'),
#  ('IoT technologies are at their infant stages however many new \n'
#   'developments have occurred in the integration of objects with sensors in '
#   'the Internet',
#   'NNP',
#   'O'),
#  ('The development of IoT involves \n'
#   'many issues such as infrastructure communications interfaces protocols and '
#   'standards',
#   'NNP',
#   'O'),
#  ('The objective of this paper is to give general concept of IoT the '
#   'architecture and layers in IoT some basic terms \n'
#   'associated with it and the services provided',
#   'NNP',
#   'O'),
#  ('II', 'NNP', 'O'),
#  ('CONCEPT OF IOT \n'
#   '   \n'
#   ' Kevin Ashton firstly proposed the concept of IoT in 1999 and he referred '
#   'the IoT as uniquely identifiable connected \n'
#   'objects with radiofrequency identification RFID technology',
#   'NNP',
#   'O'),
#  ('However the exact definition of IoT is still in the \n'
#   'forming process that is subject to the perspectives taken',
#   'NNP',
#   'O'),
#  ('IoT was generally defined as “dynamic global network \n'
#   'infrastructure with selfconfiguring capabilities based on standards and '
#   'communication protocols”',
#   'NNP',
#   'O'),
#  ('Fig21 Evolution of Internet 1', 'NNP', 'O')]

# %%
import pandas as pd
list1 = [10,20,30,40]
list2 = [40,30,20,10]
col1 = "X"
col2 = "Y"
data = pd.DataFrame({col1:list1,col2:list2})
data.to_excel('sample_data.xlsx', sheet_name='sheet1', index=False)

# %%
' '.join(exmpl_filtered_sw)
# Out:
# 'IARJSET \n \nISSN Online 23938021 \n  \n \nISSN Print 23941588 \n \n        International Advanced Research Journal in Science Engineering and Technology \nISO 32972007 Certified \nVol 5 Issue 1 January 2018 \n \nCopyright to IARJSET \n                                             DOI  1017148IARJSET2018517                                                             41 \nIntroduction to IOT \n \nPradyumna Gokhale1 Omkar Bhat2 Sagar Bhat3 \nIT Dept Smt Kashibai Navale College of Engineering13 \n \nAbstract The phrase Internet of Things IoT refers to connecting various physical devices and objects throughout the \nworld via internet The term IoT was firstly proposed by Kevin Ashton in 1999The following section illustrates basics \nof IoT It deals with various layers used in IoT and some basic terms related to it It is basically expansion of services \nprovided by Internet This section also presents the architecture of IoT For example when the household devices of \nour daily life connect with the internet the system can be called a SmartHome in IoT environment The IoT is not just \ndeep vision for future It is already under implementation and is having an impact on more than just technological \ndevelopment Keywords Internet of Things IoT Service Oriented Architecture SoA I INTRODUCTION \n \nThe Internet of Things IoT is the network of physical objects—devices instruments vehicles buildings and other \nitems embedded with electronics circuits software sensors and network connectivity that enables these objects to \ncollect and exchange data The Internet of Things allows objects to be sensed and controlled remotely across existing \nnetwork infrastructure creating opportunities for more direct integration of the physical world into computerbased \nsystems and resulting in improved efficiency and accuracy The concept of a network of smart devices was discussed as early as 1982 with a modified Coke machine at Carnegie \nMellon University becoming the first internetconnected appliance 3 able to report its inventory and whether newly \nloaded drinks were cold Kevin Ashton born 1968 is a British technology pioneer who is known for inventing the \nterm the Internet of Things to describe a system where the Internet is connected to the physical world via ubiquitous \nsensors IoT is able to interact without human intervention Some preliminary IoT applications have been already developed in \nhealthcare transportation and automotive industries IoT technologies are at their infant stages however many new \ndevelopments have occurred in the integration of objects with sensors in the Internet The development of IoT involves \nmany issues such as infrastructure communications interfaces protocols and standards The objective of this paper is to give general concept of IoT the architecture and layers in IoT some basic terms \nassociated with it and the services provided II CONCEPT OF IOT \n   \n Kevin Ashton firstly proposed the concept of IoT in 1999 and he referred the IoT as uniquely identifiable connected \nobjects with radiofrequency identification RFID technology However the exact definition of IoT is still in the \nforming process that is subject to the perspectives taken IoT was generally defined as “dynamic global network \ninfrastructure with selfconfiguring capabilities based on standards and communication protocols” Fig21 Evolution of Internet 1'

# %%
text1 = NER(text)
displacy.render(text1,style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">IARJSET </br> </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ISSN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (Online)
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2393-8021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  </br>  </br> </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ISSN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (Print)
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2394-1588
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  </br> </br>        International Advanced Research Journal in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Science, Engineering and Technology
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  </br>ISO 3297:2007 Certified </br>Vol.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , Issue
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     January 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  </br> </br>Copyright to IARJSET </br>                                             DOI
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10.17148
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# /
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IARJSET.2018.517
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     41
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  </br>Introduction to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IOT
#
# Pradyumna Gokhale1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Omkar Bhat2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sagar Bhat3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  </br>IT Dept.,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Smt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Kashibai Navale College of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Engineering1-3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  </br> </br>Abstract: The phrase Internet of Things (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IoT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) refers to connecting various physical devices and objects throughout the </br>world via internet. The term
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IoT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  was
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     firstly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  proposed by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kevin Ashton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1999.The
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  following section illustrates basics </br>of IoT. It deals with various layers used in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IoT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and some basic terms related to it. It is basically expansion of services </br>provided by Internet. This section also presents the architecture of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IoT.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  For example, when the household devices of </br>our daily life connect with the internet the s
