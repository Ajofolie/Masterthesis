# %%
import PreProcessMetadata
import PreProcess_NLP
import math
import pandas as pd
import networkx as nx
from matplotlib import cm
import pathlib
import matplotlib.pyplot as plt
import matplotlib.colors as pltcol
pd.set_option('display.max_colwidth', 200)
# %matplotlib inline

# %%
def query(news_df, conf):

  try:
    conf = conf*(100)
    question = input()
    question_kg = get_KG(nlp(question))
    query_param = [i for i,j in enumerate(question_kg) if j != '']
    
    columns  = ["subject", "links", "object"]
    col_dict = {}
    for i, j in enumerate(columns):
      col_dict[i] = j

    set_dict = {}
    for x in query_param:
      set_dict[col_dict[x]] = process.extractOne(question_kg[x], list(news_data[col_dict[x]]))[0]
    
    col_set_list = list(set_dict)
    query_key = []
    for x in columns:
      if x not in col_set_list:
        query_key.append(x)
    
    possible_sets = []
    for i in range(news_df.shape[0]):
      possible_answers = {}
      key_1 = news_df[col_set_list[0]].iloc[i] 
      key_2 = news_df[col_set_list[1]].iloc[i] 
      v_1 = set_dict[col_set_list[0]]
      v_2 = set_dict[col_set_list[1]]
      s1 = fuzz.WRatio(key_1, v_1)
      s2 = fuzz.WRatio(key_2, v_2)
      if s1 > conf and s2 > conf:
        possible_answers[query_key[0]] = news_df[query_key[0]].iloc[i] 
        possible_answers['original-source'] = news_df['headlines'].iloc[i]
        possible_answers['score'] = (s1 + s2)/2 
        possible_sets.append(possible_answers)
    return possible_sets

  except Exception as e:
    pass
    return e

# %%
#Erzeuge Knoten, Kanten aus Datei mit Metadaten
def get_entity_rel(meta, KG_entities, keyword_list_paper, keyword_list_con):
    
    for i in range(len(meta)):
        cur_authors =  meta['Authors'][i].split(',')

        #Kantenerstellung zwischen allen Titeln und Erstellungsdatum als Attribut
        KG_entities.add_node(meta['Titles'][i], date=meta['Date'], color=0.8) #Attribute können auch die Keywords sein, die üner NLP generiert wurden
        KG_entities.add_node(meta['Conference'][i], color=3.2)
        #Kantenerstellung zwischen Überklasse paper und allen Titeln 
        KG_entities.add_edge('Paper', meta['Titles'][i], label='ist')
        #Beziehung zwischen Überklasse Konferenz und allen Konferenztiteln
        KG_entities.add_edge('Konferenz', meta['Conference'][i], label='ist')

        KG_entities.add_edge(meta['Titles'][i], meta['Conference'][i], label='ist Teil von')

        for author in cur_authors:
            KG_entities.add_node(author, color=2)
            KG_entities.add_edge(author, meta['Titles'][i], label='hat verfasst')
            KG_entities.add_edge('Autor', author, label='ist')
    #Themen paper
        for j in range(len(keyword_list_paper['keywords'])):
            if keyword_list_paper['relevance'][j] > 0.3:
                if not keyword_list_paper['keywords'][j] in KG_entities.nodes:
                    KG_entities.add_node(keyword_list_paper['keywords'][j], color=10.5)
                    KG_entities.add_edge('Themengebiet', keyword_list_paper['keywords'][j], label='ist')
                    if meta['Titles'][i] == keyword_list_paper['paper'][j]:
                        KG_entities.add_edge(meta['Titles'][i], keyword_list_paper['keywords'][j], label='thematisiert')
        #Themen Konferenzen     
        for j in range(len(keyword_list_con['keywords'])):
            if keyword_list_con['relevance'][j] > 0.43:
                if not keyword_list_con['keywords'][j] in KG_entities.nodes:
                    KG_entities.add_node(keyword_list_con['keywords'][j], color=10.2)
                    KG_entities.add_edge('Themengebiet', keyword_list_con['keywords'][j], label='ist')
                    if meta['Conference'][i] == keyword_list_con['conference'][j]:
                        KG_entities.add_edge(meta['Conference'][i], keyword_list_con['keywords'][j], label="thematisiert")

    return KG_entities

# %%
#Farbschema des Graphen
def kg_colors(graph, vmin=0, vmax=7):
    cnorm = pltcol.Normalize(vmin=vmin, vmax=vmax)
    cpick = cm.ScalarMappable(norm=cnorm, cmap='turbo')
    cpick.set_array([])
    val_map = {}
    for k, v in nx.get_node_attributes(graph, 'color').items():
        val_map[k] = cpick.to_rgba(v)
    colors = []
    for node in graph.nodes():
        colors.append(val_map[node])
    return colors

# %%
# Einlesen der PDF's

pdf_path = ('C:/Users/Jana/LabCode/PDF')
p = pathlib.Path(pdf_path)
files_path = list(p.glob('*.pdf'))

pdf_path_conference = ('C:/Users/Jana/LabCode/AimsAndScope')
p_conference = pathlib.Path(pdf_path_conference)
files_path_conference = list(p_conference.glob('*.pdf'))

path = 'C:/Users/Jana/LabCode/'

df_pdf_meta = PreProcessMetadata.read_paper_meta(path)
PreProcessMetadata.write_paper_meta(path)
PreProcessMetadata.write_conference_meta(path, df_pdf_meta)
corpus = PreProcess_NLP.build_corpus(files_path)
conference_corpus = PreProcess_NLP.build_conference(files_path_conference)
    
#print(range(len(corpus['title'])))
#print(corpus)

keyword_list, conference_list = PreProcess_NLP.generate_keywords(corpus, conference_corpus)

# %%
#Initialerstellung Graph
G_KG= nx.DiGraph()


#Erstellung initial fester Knoten
G_KG.add_node("Paper", color=0.9)
G_KG.add_node("Autor", color=2)
G_KG.add_node("Konferenz", color=3)
G_KG.add_node("Themengebiet", color=10)

#print(type(keyword_list))
#print(range(len(keyword_list['keywords'])))
#print(range(len(df_pdf_meta)))


G_KG = get_entity_rel(df_pdf_meta, G_KG, keyword_list, conference_list)

colors = kg_colors(G_KG)

# %%
#Ausgabe Graph
plt.figure(figsize=(25,15))
pos = nx.spring_layout(G_KG, k=10/math.sqrt(G_KG.order())) # richtiges Layout noch finden
d = dict(G_KG.degree)


pos = nx.spring_layout(G_KG)  #setting the positions with respect to G, not k.


#print(G_Meta['Konferenz','Paper'])
nx.draw_networkx(G_KG, with_labels=True, pos=pos, node_size=[v * 5 for v in d.values()], node_color=colors, edge_color= 'grey', font_family = 'Arial')
plt.show()

# %%
nx.info(G_KG)
# Out:
# C:\Users\Jana\AppData\Local\Temp\ipykernel_25948\1029462642.py:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   nx.info(G_KG)
# 'DiGraph with 1265 nodes and 1708 edges'

# %%
#G_KG.in_edges('Themengebiet')
G_KG.out_edges('Themengebiet')
# Out:
# OutEdgeDataView([('Themengebiet', 'mobility robustness optimization'), ('Themengebiet', 'future mobile communication'), ('Themengebiet', 'vehicular technology'), ('Themengebiet', 'optimization models future'), ('Themengebiet', 'networks 5g network'), ('Themengebiet', 'parametric neural networks'), ('Themengebiet', 'high energy physics'), ('Themengebiet', 'fisica nucleare infn'), ('Themengebiet', 'pnn leverages multiple'), ('Themengebiet', 'claim audiogram'), ('Themengebiet', 'digitization tool audiological'), ('Themengebiet', 'extracting hearing thresholds'), ('Themengebiet', 'faxed audiology report'), ('Themengebiet', 'hearing 000 000'), ('Themengebiet', 'noise workplace fact'), ('Themengebiet', 'source code digitization'), ('Themengebiet', 'workplace safety insurance'), ('Themengebiet', 'thresholds scanned faxed'), ('Themengebiet', 'operational failures dns'), ('Themengebiet', 'issues mining dns'), ('Themengebiet', 'dns infrastructure systems'), ('Themengebiet', 'dns rare study'), ('Themengebiet', 'better understanding dns'), ('Themengebiet', 'dataset billion dns'), ('Themengebiet', 'scale dns logs'), ('Themengebiet', 'users mitigate dns'), ('Themengebiet', 'friendly domain name'), ('Themengebiet', 'dns forums xianran'), ('Themengebiet', 'name system'), ('Themengebiet', 'logs name though'), ('Themengebiet', 'digital object identifier'), ('Themengebiet', 'distributed recursive resolvers'), ('Themengebiet', '2047476 abstract domain'), ('Themengebiet', 'internet applications'), ('Themengebiet', 'issues mining'), ('Themengebiet', 'cycling routes'), ('Themengebiet', 'evolutionary algorithm generating'), ('Themengebiet', 'route generation based'), ('Themengebiet', 'geographical property graphs'), ('Themengebiet', 'graph intersections cycling'), ('Themengebiet', 'method generating cycling'), ('Themengebiet', 'roads shown generated'), ('Themengebiet', 'paths property'), ('Themengebiet', 'hesitant fuzzy sets'), ('Themengebiet', 'fuzzy set similarity'), ('Themengebiet', 'scholars study fuzzy'), ('Themengebiet', 'express uncertainty subjective'), ('Themengebiet', 'missing preference information'), ('Themengebiet', 'decision evaluation information'), ('Themengebiet', 'pickup delivery nodes'), ('Themengebiet', 'handling cost smmpdph'), ('Themengebiet', 'handling cost omni'), ('Themengebiet', 'travel cost handling'), ('Themengebiet', 'total demand need'), ('Themengebiet', 'programming formulations problem'), ('Themengebiet', 'logistics'), ('Themengebiet', 'incurred additional operations'), ('Themengebiet', 'mile delivery yali'), ('Themengebiet', 'nodes provide require'), ('Themengebiet', 'loading commodities multiple'), ('Themengebiet', 'capacity driving mileage'), ('Themengebiet', 'unloading policy take'), ('Themengebiet', 'obtain routing plan'), ('Themengebiet', 'multiplications using reram'), ('Themengebiet', 'binary vector matrix'), ('Themengebiet', 'matrix multiplications vmms'), ('Themengebiet', 'reliability aspects binary'), ('Themengebiet', 'heavily rely vector'), ('Themengebiet', 'dot product abstract'), ('Themengebiet', 'operations neuromorphic algorithms'), ('Themengebiet', 'memristive devices promising'), ('Themengebiet', 'metric cell membrane'), ('Themengebiet', 'simulated human cell'), ('Themengebiet', 'patches human cell'), ('Themengebiet', 'membrane cancer research'), ('Themengebiet', 'biology informed similarity'), ('Themengebiet', 'cancer biology application'), ('Themengebiet', 'carbon footprint iot'), ('Themengebiet', 'iot many social'), ('Themengebiet', 'iot utility architecture'), ('Themengebiet', 'network uses renewable'), ('Themengebiet', 'optimize energy consumption'), ('Themengebiet', 'devices moni tor'), ('Themengebiet', 'communicates via lora'), ('Themengebiet', 'neural networks alzheimer'), ('Themengebiet', 'disease neuroimaging initiative'), ('Themengebiet', 'incomplete medical datasets'), ('Themengebiet', 'training highly incomplete'), ('Themengebiet', 'sweden clinical memory'), ('Themengebiet', 'cluster dete ...
